# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import*
from pyspark.sql.types import*
import os
import sys

# %%
spark = SparkSession.builder \
    .appName("challan") \
    .master("local[*]") \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/08 09:11:30 WARN Utils: Your hostname, LAPTOP-A2FP9AQK, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/03/08 09:11:30 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/08 09:11:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
file_path = "/home/somnath/coding/pyspark/input_data/echallan_daily_data.csv"
path = "/home/somnath/coding/pyspark/output_data"

# %%
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("mode","PERMISSIVE") \
    .load(file_path)

# %%
df.show(5)
# Out:
# +----------+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+
# |      date|totalChallan|disposedChallan|pendingChallan|pendingAmount|disposedAmount|totalAmount|pendingCourt|disposedCourt|totalCourt|
# +----------+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+
# |2015-01-01|         120|             29|            91|       588600|        116860|     705460|           1|            0|         1|
# |2015-01-02|         162|             39|           123|       663350|        281425|     944775|           1|            1|         2|
# |2015-01-03|         122|             34|            88|       596900|        286950|     883850|           4|            1|         5|
# |2015-01-04|         116|             27|            89|       967350|        301600|    1268950|           3|            2|         5|
# |2015-01-05|         162|             28|           134|       877654|        103000|     980654|           2|            0|         2|
# +----------+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+
# only showing top 5 rows

# %%
df.collect()
# Out:
# [Row(date=datetime.date(2015, 1, 1), totalChallan=120, disposedChallan=29, pendingChallan=91, pendingAmount=588600, disposedAmount=116860, totalAmount=705460, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 1, 2), totalChallan=162, disposedChallan=39, pendingChallan=123, pendingAmount=663350, disposedAmount=281425, totalAmount=944775, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 1, 3), totalChallan=122, disposedChallan=34, pendingChallan=88, pendingAmount=596900, disposedAmount=286950, totalAmount=883850, pendingCourt=4, disposedCourt=1, totalCourt=5),
#  Row(date=datetime.date(2015, 1, 4), totalChallan=116, disposedChallan=27, pendingChallan=89, pendingAmount=967350, disposedAmount=301600, totalAmount=1268950, pendingCourt=3, disposedCourt=2, totalCourt=5),
#  Row(date=datetime.date(2015, 1, 5), totalChallan=162, disposedChallan=28, pendingChallan=134, pendingAmount=877654, disposedAmount=103000, totalAmount=980654, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 1, 6), totalChallan=104, disposedChallan=24, pendingChallan=80, pendingAmount=597100, disposedAmount=149500, totalAmount=746600, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 1, 7), totalChallan=108, disposedChallan=22, pendingChallan=86, pendingAmount=728650, disposedAmount=144600, totalAmount=873250, pendingCourt=3, disposedCourt=1, totalCourt=4),
#  Row(date=datetime.date(2015, 1, 8), totalChallan=169, disposedChallan=37, pendingChallan=132, pendingAmount=886802, disposedAmount=156300, totalAmount=1043102, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 1, 9), totalChallan=137, disposedChallan=30, pendingChallan=107, pendingAmount=852650, disposedAmount=282200, totalAmount=1134850, pendingCourt=7, disposedCourt=0, totalCourt=7),
#  Row(date=datetime.date(2015, 1, 10), totalChallan=108, disposedChallan=35, pendingChallan=73, pendingAmount=668450, disposedAmount=183380, totalAmount=851830, pendingCourt=6, disposedCourt=0, totalCourt=6),
#  Row(date=datetime.date(2015, 1, 11), totalChallan=116, disposedChallan=18, pendingChallan=98, pendingAmount=809900, disposedAmount=109200, totalAmount=919100, pendingCourt=3, disposedCourt=0, totalCourt=3),
#  Row(date=datetime.date(2015, 1, 12), totalChallan=130, disposedChallan=19, pendingChallan=111, pendingAmount=650150, disposedAmount=85600, totalAmount=735750, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 1, 13), totalChallan=115, disposedChallan=24, pendingChallan=91, pendingAmount=579000, disposedAmount=83235, totalAmount=662235, pendingCourt=8, disposedCourt=3, totalCourt=11),
#  Row(date=datetime.date(2015, 1, 14), totalChallan=68, disposedChallan=15, pendingChallan=53, pendingAmount=352850, disposedAmount=77050, totalAmount=429900, pendingCourt=6, disposedCourt=0, totalCourt=6),
#  Row(date=datetime.date(2015, 1, 15), totalChallan=116, disposedChallan=30, pendingChallan=86, pendingAmount=650400, disposedAmount=148100, totalAmount=798500, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 1, 16), totalChallan=148, disposedChallan=27, pendingChallan=121, pendingAmount=555800, disposedAmount=53800, totalAmount=609600, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 1, 17), totalChallan=128, disposedChallan=37, pendingChallan=91, pendingAmount=610100, disposedAmount=137800, totalAmount=747900, pendingCourt=2, disposedCourt=2, totalCourt=4),
#  Row(date=datetime.date(2015, 1, 18), totalChallan=84, disposedChallan=22, pendingChallan=62, pendingAmount=450350, disposedAmount=52300, totalAmount=502650, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 1, 19), totalChallan=134, disposedChallan=32, pendingChallan=102, pendingAmount=567500, disposedAmount=130900, totalAmount=698400, pendingCourt=7, disposedCourt=2, totalCourt=9),
#  Row(date=datetime.date(2015, 1, 20), totalChallan=137, disposedChallan=33, pendingChallan=104, pendingAmount=584350, disposedAmount=158600, totalAmount=742950, pendingCourt=7, disposedCourt=0, totalCourt=7),
#  Row(date=datetime.date(2015, 1, 21), totalChallan=112, disposedChallan=23, pendingChallan=89, pendingAmount=634749, disposedAmount=56400, totalAmount=691149, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 1, 22), totalChallan=130, disposedChallan=27, pendingChallan=103, pendingAmount=670600, disposedAmount=106800, totalAmount=777400, pendingCourt=2, disposedCourt=3, totalCourt=5),
#  Row(date=datetime.date(2015, 1, 23), totalChallan=93, disposedChallan=25, pendingChallan=68, pendingAmount=354000, disposedAmount=179550, totalAmount=533550, pendingCourt=7, disposedCourt=0, totalCourt=7),
#  Row(date=datetime.date(2015, 1, 24), totalChallan=74, disposedChallan=17, pendingChallan=57, pendingAmount=447450, disposedAmount=90800, totalAmount=538250, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 1, 25), totalChallan=97, disposedChallan=30, pendingChallan=67, pendingAmount=617050, disposedAmount=161700, totalAmount=778750, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 1, 26), totalChallan=75, disposedChallan=13, pendingChallan=62, pendingAmount=410350, disposedAmount=43250, totalAmount=453600, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 1, 27), totalChallan=83, disposedChallan=33, pendingChallan=50, pendingAmount=319620, disposedAmount=164500, totalAmount=484120, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 1, 28), totalChallan=134, disposedChallan=23, pendingChallan=111, pendingAmount=586950, disposedAmount=50750, totalAmount=637700, pendingCourt=4, disposedCourt=1, totalCourt=5),
#  Row(date=datetime.date(2015, 1, 29), totalChallan=101, disposedChallan=29, pendingChallan=72, pendingAmount=442198, disposedAmount=233690, totalAmount=675888, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 1, 30), totalChallan=109, disposedChallan=28, pendingChallan=81, pendingAmount=681600, disposedAmount=196030, totalAmount=877630, pendingCourt=3, disposedCourt=1, totalCourt=4),
#  Row(date=datetime.date(2015, 1, 31), totalChallan=89, disposedChallan=19, pendingChallan=70, pendingAmount=563971, disposedAmount=111300, totalAmount=675271, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 2, 1), totalChallan=69, disposedChallan=21, pendingChallan=48, pendingAmount=413896, disposedAmount=68200, totalAmount=482096, pendingCourt=3, disposedCourt=2, totalCourt=5),
#  Row(date=datetime.date(2015, 2, 2), totalChallan=116, disposedChallan=32, pendingChallan=84, pendingAmount=607850, disposedAmount=145800, totalAmount=753650, pendingCourt=6, disposedCourt=0, totalCourt=6),
#  Row(date=datetime.date(2015, 2, 3), totalChallan=126, disposedChallan=36, pendingChallan=90, pendingAmount=797798, disposedAmount=184200, totalAmount=981998, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 2, 4), totalChallan=125, disposedChallan=37, pendingChallan=88, pendingAmount=656550, disposedAmount=204036, totalAmount=860586, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 2, 5), totalChallan=118, disposedChallan=32, pendingChallan=86, pendingAmount=758500, disposedAmount=146720, totalAmount=905220, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 2, 6), totalChallan=101, disposedChallan=32, pendingChallan=69, pendingAmount=553250, disposedAmount=110000, totalAmount=663250, pendingCourt=4, disposedCourt=1, totalCourt=5),
#  Row(date=datetime.date(2015, 2, 7), totalChallan=77, disposedChallan=29, pendingChallan=48, pendingAmount=401850, disposedAmount=108600, totalAmount=510450, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 2, 8), totalChallan=78, disposedChallan=27, pendingChallan=51, pendingAmount=273650, disposedAmount=82100, totalAmount=355750, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 2, 9), totalChallan=116, disposedChallan=37, pendingChallan=79, pendingAmount=604400, disposedAmount=140600, totalAmount=745000, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 2, 10), totalChallan=190, disposedChallan=54, pendingChallan=136, pendingAmount=1101190, disposedAmount=205500, totalAmount=1306690, pendingCourt=5, disposedCourt=0, totalCourt=5),
#  Row(date=datetime.date(2015, 2, 11), totalChallan=213, disposedChallan=54, pendingChallan=159, pendingAmount=984522, disposedAmount=241900, totalAmount=1226422, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 2, 12), totalChallan=230, disposedChallan=56, pendingChallan=174, pendingAmount=1046250, disposedAmount=200350, totalAmount=1246600, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 2, 13), totalChallan=160, disposedChallan=46, pendingChallan=114, pendingAmount=927550, disposedAmount=145035, totalAmount=1072585, pendingCourt=2, disposedCourt=2, totalCourt=4),
#  Row(date=datetime.date(2015, 2, 14), totalChallan=129, disposedChallan=23, pendingChallan=106, pendingAmount=561350, disposedAmount=55310, totalAmount=616660, pendingCourt=3, disposedCourt=0, totalCourt=3),
#  Row(date=datetime.date(2015, 2, 15), totalChallan=89, disposedChallan=34, pendingChallan=55, pendingAmount=318900, disposedAmount=109300, totalAmount=428200, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 2, 16), totalChallan=133, disposedChallan=29, pendingChallan=104, pendingAmount=735620, disposedAmount=116600, totalAmount=852220, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 2, 17), totalChallan=55, disposedChallan=18, pendingChallan=37, pendingAmount=168300, disposedAmount=60600, totalAmount=228900, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 2, 18), totalChallan=141, disposedChallan=34, pendingChallan=107, pendingAmount=687850, disposedAmount=129800, totalAmount=817650, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 2, 19), totalChallan=254, disposedChallan=76, pendingChallan=178, pendingAmount=938700, disposedAmount=306050, totalAmount=1244750, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 2, 20), totalChallan=136, disposedChallan=30, pendingChallan=106, pendingAmount=814350, disposedAmount=97000, totalAmount=911350, pendingCourt=3, disposedCourt=0, totalCourt=3),
#  Row(date=datetime.date(2015, 2, 21), totalChallan=91, disposedChallan=24, pendingChallan=67, pendingAmount=376900, disposedAmount=145650, totalAmount=522550, pendingCourt=4, disposedCourt=1, totalCourt=5),
#  Row(date=datetime.date(2015, 2, 22), totalChallan=87, disposedChallan=16, pendingChallan=71, pendingAmount=365800, disposedAmount=26500, totalAmount=392300, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 2, 23), totalChallan=97, disposedChallan=15, pendingChallan=82, pendingAmount=622500, disposedAmount=68500, totalAmount=691000, pendingCourt=3, disposedCourt=0, totalCourt=3),
#  Row(date=datetime.date(2015, 2, 24), totalChallan=112, disposedChallan=30, pendingChallan=82, pendingAmount=545150, disposedAmount=201160, totalAmount=746310, pendingCourt=1, disposedCourt=2, totalCourt=3),
#  Row(date=datetime.date(2015, 2, 25), totalChallan=110, disposedChallan=37, pendingChallan=73, pendingAmount=463000, disposedAmount=122950, totalAmount=585950, pendingCourt=4, disposedCourt=1, totalCourt=5),
#  Row(date=datetime.date(2015, 2, 26), totalChallan=130, disposedChallan=44, pendingChallan=86, pendingAmount=860450, disposedAmount=189700, totalAmount=1050150, pendingCourt=1, disposedCourt=2, totalCourt=3),
#  Row(date=datetime.date(2015, 2, 27), totalChallan=105, disposedChallan=35, pendingChallan=70, pendingAmount=529650, disposedAmount=166000, totalAmount=695650, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 2, 28), totalChallan=58, disposedChallan=16, pendingChallan=42, pendingAmount=310650, disposedAmount=68000, totalAmount=378650, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 3, 1), totalChallan=61, disposedChallan=14, pendingChallan=47, pendingAmount=373700, disposedAmount=92700, totalAmount=466400, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 3, 2), totalChallan=101, disposedChallan=19, pendingChallan=82, pendingAmount=787050, disposedAmount=28000, totalAmount=815050, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 3, 3), totalChallan=144, disposedChallan=27, pendingChallan=117, pendingAmount=908550, disposedAmount=171500, totalAmount=1080050, pendingCourt=6, disposedCourt=1, totalCourt=7),
#  Row(date=datetime.date(2015, 3, 4), totalChallan=127, disposedChallan=26, pendingChallan=101, pendingAmount=805500, disposedAmount=125550, totalAmount=931050, pendingCourt=4, disposedCourt=0, totalCourt=4),
#  Row(date=datetime.date(2015, 3, 5), totalChallan=75, disposedChallan=19, pendingChallan=56, pendingAmount=357000, disposedAmount=133500, totalAmount=490500, pendingCourt=4, disposedCourt=1, totalCourt=5),
#  Row(date=datetime.date(2015, 3, 6), totalChallan=10, disposedChallan=7, pendingChallan=3, pendingAmount=20400, disposedAmount=34000, totalAmount=54400, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 3, 7), totalChallan=111, disposedChallan=23, pendingChallan=88, pendingAmount=457850, disposedAmount=69900, totalAmount=527750, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 3, 8), totalChallan=80, disposedChallan=22, pendingChallan=58, pendingAmount=453050, disposedAmount=99300, totalAmount=552350, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 3, 9), totalChallan=129, disposedChallan=28, pendingChallan=101, pendingAmount=626400, disposedAmount=105850, totalAmount=732250, pendingCourt=4, disposedCourt=1, totalCourt=5),
#  Row(date=datetime.date(2015, 3, 10), totalChallan=136, disposedChallan=35, pendingChallan=101, pendingAmount=734350, disposedAmount=163160, totalAmount=897510, pendingCourt=5, disposedCourt=2, totalCourt=7),
#  Row(date=datetime.date(2015, 3, 11), totalChallan=131, disposedChallan=43, pendingChallan=88, pendingAmount=760160, disposedAmount=288000, totalAmount=1048160, pendingCourt=3, disposedCourt=0, totalCourt=3),
#  Row(date=datetime.date(2015, 3, 12), totalChallan=120, disposedChallan=26, pendingChallan=94, pendingAmount=672050, disposedAmount=190410, totalAmount=862460, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 3, 13), totalChallan=103, disposedChallan=35, pendingChallan=68, pendingAmount=560600, disposedAmount=153320, totalAmount=713920, pendingCourt=3, disposedCourt=4, totalCourt=7),
#  Row(date=datetime.date(2015, 3, 14), totalChallan=114, disposedChallan=30, pendingChallan=84, pendingAmount=538600, disposedAmount=147610, totalAmount=686210, pendingCourt=0, disposedCourt=2, totalCourt=2),
#  Row(date=datetime.date(2015, 3, 15), totalChallan=129, disposedChallan=43, pendingChallan=86, pendingAmount=404150, disposedAmount=169449, totalAmount=573599, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 3, 16), totalChallan=121, disposedChallan=25, pendingChallan=96, pendingAmount=700600, disposedAmount=104130, totalAmount=804730, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 3, 17), totalChallan=112, disposedChallan=24, pendingChallan=88, pendingAmount=588900, disposedAmount=172548, totalAmount=761448, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 3, 18), totalChallan=161, disposedChallan=42, pendingChallan=119, pendingAmount=994400, disposedAmount=281950, totalAmount=1276350, pendingCourt=3, disposedCourt=1, totalCourt=4),
#  Row(date=datetime.date(2015, 3, 19), totalChallan=156, disposedChallan=47, pendingChallan=109, pendingAmount=1320100, disposedAmount=328250, totalAmount=1648350, pendingCourt=4, disposedCourt=4, totalCourt=8),
#  Row(date=datetime.date(2015, 3, 20), totalChallan=99, disposedChallan=26, pendingChallan=73, pendingAmount=378401, disposedAmount=171554, totalAmount=549955, pendingCourt=6, disposedCourt=1, totalCourt=7),
#  Row(date=datetime.date(2015, 3, 21), totalChallan=127, disposedChallan=30, pendingChallan=97, pendingAmount=574250, disposedAmount=121750, totalAmount=696000, pendingCourt=0, disposedCourt=2, totalCourt=2),
#  Row(date=datetime.date(2015, 3, 22), totalChallan=122, disposedChallan=41, pendingChallan=81, pendingAmount=519200, disposedAmount=206380, totalAmount=725580, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 3, 23), totalChallan=123, disposedChallan=27, pendingChallan=96, pendingAmount=729000, disposedAmount=53500, totalAmount=782500, pendingCourt=8, disposedCourt=0, totalCourt=8),
#  Row(date=datetime.date(2015, 3, 24), totalChallan=135, disposedChallan=41, pendingChallan=94, pendingAmount=764750, disposedAmount=234600, totalAmount=999350, pendingCourt=4, disposedCourt=0, totalCourt=4),
#  Row(date=datetime.date(2015, 3, 25), totalChallan=125, disposedChallan=28, pendingChallan=97, pendingAmount=771050, disposedAmount=106838, totalAmount=877888, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 3, 26), totalChallan=110, disposedChallan=31, pendingChallan=79, pendingAmount=536650, disposedAmount=139430, totalAmount=676080, pendingCourt=6, disposedCourt=2, totalCourt=8),
#  Row(date=datetime.date(2015, 3, 27), totalChallan=67, disposedChallan=23, pendingChallan=44, pendingAmount=328200, disposedAmount=124324, totalAmount=452524, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 3, 28), totalChallan=84, disposedChallan=22, pendingChallan=62, pendingAmount=359700, disposedAmount=137900, totalAmount=497600, pendingCourt=0, disposedCourt=2, totalCourt=2),
#  Row(date=datetime.date(2015, 3, 29), totalChallan=100, disposedChallan=24, pendingChallan=76, pendingAmount=411800, disposedAmount=75900, totalAmount=487700, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 3, 30), totalChallan=102, disposedChallan=21, pendingChallan=81, pendingAmount=508630, disposedAmount=60720, totalAmount=569350, pendingCourt=2, disposedCourt=2, totalCourt=4),
#  Row(date=datetime.date(2015, 3, 31), totalChallan=96, disposedChallan=26, pendingChallan=70, pendingAmount=383800, disposedAmount=104300, totalAmount=488100, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 4, 1), totalChallan=73, disposedChallan=22, pendingChallan=51, pendingAmount=335100, disposedAmount=113775, totalAmount=448875, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 4, 2), totalChallan=105, disposedChallan=31, pendingChallan=74, pendingAmount=426747, disposedAmount=117960, totalAmount=544707, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 4, 3), totalChallan=100, disposedChallan=24, pendingChallan=76, pendingAmount=621300, disposedAmount=121800, totalAmount=743100, pendingCourt=3, disposedCourt=0, totalCourt=3),
#  Row(date=datetime.date(2015, 4, 4), totalChallan=83, disposedChallan=14, pendingChallan=69, pendingAmount=379600, disposedAmount=37060, totalAmount=416660, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 4, 5), totalChallan=105, disposedChallan=29, pendingChallan=76, pendingAmount=510430, disposedAmount=139950, totalAmount=650380, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 4, 6), totalChallan=108, disposedChallan=23, pendingChallan=85, pendingAmount=663120, disposedAmount=67200, totalAmount=730320, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 4, 7), totalChallan=119, disposedChallan=22, pendingChallan=97, pendingAmount=586650, disposedAmount=109790, totalAmount=696440, pendingCourt=7, disposedCourt=0, totalCourt=7),
#  Row(date=datetime.date(2015, 4, 8), totalChallan=125, disposedChallan=39, pendingChallan=86, pendingAmount=559220, disposedAmount=253410, totalAmount=812630, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 4, 9), totalChallan=128, disposedChallan=40, pendingChallan=88, pendingAmount=823300, disposedAmount=232380, totalAmount=1055680, pendingCourt=3, disposedCourt=3, totalCourt=6),
#  Row(date=datetime.date(2015, 4, 10), totalChallan=72, disposedChallan=13, pendingChallan=59, pendingAmount=503600, disposedAmount=50800, totalAmount=554400, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 4, 11), totalChallan=87, disposedChallan=36, pendingChallan=51, pendingAmount=310501, disposedAmount=109300, totalAmount=419801, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 4, 12), totalChallan=89, disposedChallan=20, pendingChallan=69, pendingAmount=385700, disposedAmount=83300, totalAmount=469000, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 4, 13), totalChallan=97, disposedChallan=24, pendingChallan=73, pendingAmount=746950, disposedAmount=100050, totalAmount=847000, pendingCourt=1, disposedCourt=3, totalCourt=4),
#  Row(date=datetime.date(2015, 4, 14), totalChallan=79, disposedChallan=19, pendingChallan=60, pendingAmount=319050, disposedAmount=90400, totalAmount=409450, pendingCourt=4, disposedCourt=0, totalCourt=4),
#  Row(date=datetime.date(2015, 4, 15), totalChallan=108, disposedChallan=29, pendingChallan=79, pendingAmount=838500, disposedAmount=197000, totalAmount=1035500, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 4, 16), totalChallan=115, disposedChallan=35, pendingChallan=80, pendingAmount=1098300, disposedAmount=202600, totalAmount=1300900, pendingCourt=3, disposedCourt=1, totalCourt=4),
#  Row(date=datetime.date(2015, 4, 17), totalChallan=83, disposedChallan=28, pendingChallan=55, pendingAmount=311000, disposedAmount=93500, totalAmount=404500, pendingCourt=4, disposedCourt=2, totalCourt=6),
#  Row(date=datetime.date(2015, 4, 18), totalChallan=82, disposedChallan=23, pendingChallan=59, pendingAmount=510770, disposedAmount=107200, totalAmount=617970, pendingCourt=4, disposedCourt=1, totalCourt=5),
#  Row(date=datetime.date(2015, 4, 19), totalChallan=63, disposedChallan=15, pendingChallan=48, pendingAmount=261350, disposedAmount=80000, totalAmount=341350, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 4, 20), totalChallan=104, disposedChallan=26, pendingChallan=78, pendingAmount=357900, disposedAmount=152700, totalAmount=510600, pendingCourt=5, disposedCourt=1, totalCourt=6),
#  Row(date=datetime.date(2015, 4, 21), totalChallan=89, disposedChallan=27, pendingChallan=62, pendingAmount=377450, disposedAmount=117900, totalAmount=495350, pendingCourt=2, disposedCourt=3, totalCourt=5),
#  Row(date=datetime.date(2015, 4, 22), totalChallan=91, disposedChallan=32, pendingChallan=59, pendingAmount=442560, disposedAmount=115800, totalAmount=558360, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 4, 23), totalChallan=97, disposedChallan=32, pendingChallan=65, pendingAmount=564100, disposedAmount=177525, totalAmount=741625, pendingCourt=3, disposedCourt=3, totalCourt=6),
#  Row(date=datetime.date(2015, 4, 24), totalChallan=72, disposedChallan=16, pendingChallan=56, pendingAmount=323900, disposedAmount=151500, totalAmount=475400, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 4, 25), totalChallan=53, disposedChallan=21, pendingChallan=32, pendingAmount=181900, disposedAmount=112550, totalAmount=294450, pendingCourt=2, disposedCourt=2, totalCourt=4),
#  Row(date=datetime.date(2015, 4, 26), totalChallan=46, disposedChallan=16, pendingChallan=30, pendingAmount=169850, disposedAmount=100700, totalAmount=270550, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 4, 27), totalChallan=85, disposedChallan=24, pendingChallan=61, pendingAmount=470250, disposedAmount=153250, totalAmount=623500, pendingCourt=4, disposedCourt=1, totalCourt=5),
#  Row(date=datetime.date(2015, 4, 28), totalChallan=100, disposedChallan=18, pendingChallan=82, pendingAmount=611000, disposedAmount=43750, totalAmount=654750, pendingCourt=4, disposedCourt=1, totalCourt=5),
#  Row(date=datetime.date(2015, 4, 29), totalChallan=64, disposedChallan=17, pendingChallan=47, pendingAmount=345200, disposedAmount=96075, totalAmount=441275, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 4, 30), totalChallan=74, disposedChallan=23, pendingChallan=51, pendingAmount=441100, disposedAmount=119500, totalAmount=560600, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 5, 1), totalChallan=63, disposedChallan=12, pendingChallan=51, pendingAmount=434440, disposedAmount=52550, totalAmount=486990, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 5, 2), totalChallan=62, disposedChallan=15, pendingChallan=47, pendingAmount=391000, disposedAmount=85350, totalAmount=476350, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 5, 3), totalChallan=46, disposedChallan=22, pendingChallan=24, pendingAmount=129000, disposedAmount=103350, totalAmount=232350, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 5, 4), totalChallan=52, disposedChallan=11, pendingChallan=41, pendingAmount=319900, disposedAmount=40438, totalAmount=360338, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 5, 5), totalChallan=92, disposedChallan=29, pendingChallan=63, pendingAmount=427098, disposedAmount=234800, totalAmount=661898, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 5, 6), totalChallan=99, disposedChallan=31, pendingChallan=68, pendingAmount=674475, disposedAmount=176600, totalAmount=851075, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 5, 7), totalChallan=93, disposedChallan=42, pendingChallan=51, pendingAmount=509100, disposedAmount=231773, totalAmount=740873, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 5, 8), totalChallan=73, disposedChallan=20, pendingChallan=53, pendingAmount=510500, disposedAmount=111500, totalAmount=622000, pendingCourt=3, disposedCourt=0, totalCourt=3),
#  Row(date=datetime.date(2015, 5, 9), totalChallan=100, disposedChallan=28, pendingChallan=72, pendingAmount=612550, disposedAmount=159550, totalAmount=772100, pendingCourt=1, disposedCourt=2, totalCourt=3),
#  Row(date=datetime.date(2015, 5, 10), totalChallan=91, disposedChallan=33, pendingChallan=58, pendingAmount=366347, disposedAmount=109500, totalAmount=475847, pendingCourt=3, disposedCourt=1, totalCourt=4),
#  Row(date=datetime.date(2015, 5, 11), totalChallan=96, disposedChallan=30, pendingChallan=66, pendingAmount=349148, disposedAmount=94633, totalAmount=443781, pendingCourt=3, disposedCourt=1, totalCourt=4),
#  Row(date=datetime.date(2015, 5, 12), totalChallan=110, disposedChallan=22, pendingChallan=88, pendingAmount=533947, disposedAmount=132760, totalAmount=666707, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 5, 13), totalChallan=110, disposedChallan=34, pendingChallan=76, pendingAmount=566200, disposedAmount=120450, totalAmount=686650, pendingCourt=3, disposedCourt=0, totalCourt=3),
#  Row(date=datetime.date(2015, 5, 14), totalChallan=114, disposedChallan=34, pendingChallan=80, pendingAmount=442646, disposedAmount=156450, totalAmount=599096, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 5, 15), totalChallan=117, disposedChallan=31, pendingChallan=86, pendingAmount=721438, disposedAmount=323950, totalAmount=1045388, pendingCourt=3, disposedCourt=1, totalCourt=4),
#  Row(date=datetime.date(2015, 5, 16), totalChallan=157, disposedChallan=44, pendingChallan=113, pendingAmount=690450, disposedAmount=202550, totalAmount=893000, pendingCourt=2, disposedCourt=2, totalCourt=4),
#  Row(date=datetime.date(2015, 5, 17), totalChallan=104, disposedChallan=21, pendingChallan=83, pendingAmount=600400, disposedAmount=74250, totalAmount=674650, pendingCourt=3, disposedCourt=0, totalCourt=3),
#  Row(date=datetime.date(2015, 5, 18), totalChallan=135, disposedChallan=28, pendingChallan=107, pendingAmount=812548, disposedAmount=96850, totalAmount=909398, pendingCourt=3, disposedCourt=1, totalCourt=4),
#  Row(date=datetime.date(2015, 5, 19), totalChallan=116, disposedChallan=27, pendingChallan=89, pendingAmount=715000, disposedAmount=92700, totalAmount=807700, pendingCourt=3, disposedCourt=0, totalCourt=3),
#  Row(date=datetime.date(2015, 5, 20), totalChallan=118, disposedChallan=34, pendingChallan=84, pendingAmount=557400, disposedAmount=223050, totalAmount=780450, pendingCourt=2, disposedCourt=2, totalCourt=4),
#  Row(date=datetime.date(2015, 5, 21), totalChallan=104, disposedChallan=20, pendingChallan=84, pendingAmount=954750, disposedAmount=87400, totalAmount=1042150, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 5, 22), totalChallan=62, disposedChallan=20, pendingChallan=42, pendingAmount=358950, disposedAmount=125899, totalAmount=484849, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 5, 23), totalChallan=81, disposedChallan=22, pendingChallan=59, pendingAmount=385500, disposedAmount=61025, totalAmount=446525, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 5, 24), totalChallan=63, disposedChallan=16, pendingChallan=47, pendingAmount=308450, disposedAmount=59350, totalAmount=367800, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 5, 25), totalChallan=108, disposedChallan=35, pendingChallan=73, pendingAmount=481650, disposedAmount=156800, totalAmount=638450, pendingCourt=4, disposedCourt=0, totalCourt=4),
#  Row(date=datetime.date(2015, 5, 26), totalChallan=77, disposedChallan=19, pendingChallan=58, pendingAmount=439950, disposedAmount=103430, totalAmount=543380, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 5, 27), totalChallan=111, disposedChallan=33, pendingChallan=78, pendingAmount=715150, disposedAmount=209300, totalAmount=924450, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 5, 28), totalChallan=94, disposedChallan=22, pendingChallan=72, pendingAmount=480300, disposedAmount=131800, totalAmount=612100, pendingCourt=5, disposedCourt=1, totalCourt=6),
#  Row(date=datetime.date(2015, 5, 29), totalChallan=97, disposedChallan=19, pendingChallan=78, pendingAmount=518250, disposedAmount=92100, totalAmount=610350, pendingCourt=6, disposedCourt=0, totalCourt=6),
#  Row(date=datetime.date(2015, 5, 30), totalChallan=105, disposedChallan=44, pendingChallan=61, pendingAmount=302800, disposedAmount=242100, totalAmount=544900, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 5, 31), totalChallan=58, disposedChallan=19, pendingChallan=39, pendingAmount=277901, disposedAmount=113200, totalAmount=391101, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 6, 1), totalChallan=107, disposedChallan=36, pendingChallan=71, pendingAmount=632450, disposedAmount=244000, totalAmount=876450, pendingCourt=3, disposedCourt=1, totalCourt=4),
#  Row(date=datetime.date(2015, 6, 2), totalChallan=98, disposedChallan=31, pendingChallan=67, pendingAmount=561550, disposedAmount=160405, totalAmount=721955, pendingCourt=6, disposedCourt=0, totalCourt=6),
#  Row(date=datetime.date(2015, 6, 3), totalChallan=156, disposedChallan=46, pendingChallan=110, pendingAmount=971600, disposedAmount=378240, totalAmount=1349840, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 6, 4), totalChallan=139, disposedChallan=41, pendingChallan=98, pendingAmount=779900, disposedAmount=200440, totalAmount=980340, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 6, 5), totalChallan=103, disposedChallan=28, pendingChallan=75, pendingAmount=678650, disposedAmount=201790, totalAmount=880440, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 6, 6), totalChallan=98, disposedChallan=26, pendingChallan=72, pendingAmount=584250, disposedAmount=163998, totalAmount=748248, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 6, 7), totalChallan=82, disposedChallan=29, pendingChallan=53, pendingAmount=431550, disposedAmount=170400, totalAmount=601950, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 6, 8), totalChallan=113, disposedChallan=36, pendingChallan=77, pendingAmount=712700, disposedAmount=173480, totalAmount=886180, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 6, 9), totalChallan=93, disposedChallan=21, pendingChallan=72, pendingAmount=591500, disposedAmount=111600, totalAmount=703100, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 6, 10), totalChallan=182, disposedChallan=68, pendingChallan=114, pendingAmount=853150, disposedAmount=344160, totalAmount=1197310, pendingCourt=1, disposedCourt=2, totalCourt=3),
#  Row(date=datetime.date(2015, 6, 11), totalChallan=112, disposedChallan=38, pendingChallan=74, pendingAmount=631100, disposedAmount=165250, totalAmount=796350, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 6, 12), totalChallan=128, disposedChallan=33, pendingChallan=95, pendingAmount=699850, disposedAmount=177750, totalAmount=877600, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 6, 13), totalChallan=96, disposedChallan=26, pendingChallan=70, pendingAmount=498248, disposedAmount=116450, totalAmount=614698, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 6, 14), totalChallan=79, disposedChallan=24, pendingChallan=55, pendingAmount=504250, disposedAmount=75600, totalAmount=579850, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 6, 15), totalChallan=124, disposedChallan=31, pendingChallan=93, pendingAmount=732950, disposedAmount=196300, totalAmount=929250, pendingCourt=4, disposedCourt=0, totalCourt=4),
#  Row(date=datetime.date(2015, 6, 16), totalChallan=95, disposedChallan=25, pendingChallan=70, pendingAmount=513700, disposedAmount=113100, totalAmount=626800, pendingCourt=8, disposedCourt=0, totalCourt=8),
#  Row(date=datetime.date(2015, 6, 17), totalChallan=103, disposedChallan=36, pendingChallan=67, pendingAmount=512320, disposedAmount=169630, totalAmount=681950, pendingCourt=5, disposedCourt=0, totalCourt=5),
#  Row(date=datetime.date(2015, 6, 18), totalChallan=116, disposedChallan=36, pendingChallan=80, pendingAmount=366400, disposedAmount=277400, totalAmount=643800, pendingCourt=18, disposedCourt=1, totalCourt=19),
#  Row(date=datetime.date(2015, 6, 19), totalChallan=79, disposedChallan=17, pendingChallan=62, pendingAmount=514590, disposedAmount=132355, totalAmount=646945, pendingCourt=6, disposedCourt=0, totalCourt=6),
#  Row(date=datetime.date(2015, 6, 20), totalChallan=118, disposedChallan=30, pendingChallan=88, pendingAmount=779800, disposedAmount=104150, totalAmount=883950, pendingCourt=12, disposedCourt=2, totalCourt=14),
#  Row(date=datetime.date(2015, 6, 21), totalChallan=109, disposedChallan=29, pendingChallan=80, pendingAmount=680698, disposedAmount=98000, totalAmount=778698, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 6, 22), totalChallan=117, disposedChallan=25, pendingChallan=92, pendingAmount=634400, disposedAmount=122400, totalAmount=756800, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 6, 23), totalChallan=88, disposedChallan=20, pendingChallan=68, pendingAmount=675030, disposedAmount=103000, totalAmount=778030, pendingCourt=4, disposedCourt=0, totalCourt=4),
#  Row(date=datetime.date(2015, 6, 24), totalChallan=79, disposedChallan=26, pendingChallan=53, pendingAmount=469390, disposedAmount=119450, totalAmount=588840, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 6, 25), totalChallan=127, disposedChallan=34, pendingChallan=93, pendingAmount=961950, disposedAmount=130700, totalAmount=1092650, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 6, 26), totalChallan=124, disposedChallan=31, pendingChallan=93, pendingAmount=1077100, disposedAmount=223575, totalAmount=1300675, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 6, 27), totalChallan=80, disposedChallan=19, pendingChallan=61, pendingAmount=434150, disposedAmount=94200, totalAmount=528350, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 6, 28), totalChallan=63, disposedChallan=10, pendingChallan=53, pendingAmount=336400, disposedAmount=32300, totalAmount=368700, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 6, 29), totalChallan=101, disposedChallan=23, pendingChallan=78, pendingAmount=518500, disposedAmount=135580, totalAmount=654080, pendingCourt=5, disposedCourt=0, totalCourt=5),
#  Row(date=datetime.date(2015, 6, 30), totalChallan=95, disposedChallan=25, pendingChallan=70, pendingAmount=423850, disposedAmount=92700, totalAmount=516550, pendingCourt=2, disposedCourt=3, totalCourt=5),
#  Row(date=datetime.date(2015, 7, 1), totalChallan=93, disposedChallan=28, pendingChallan=65, pendingAmount=672150, disposedAmount=144110, totalAmount=816260, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 7, 2), totalChallan=117, disposedChallan=34, pendingChallan=83, pendingAmount=663950, disposedAmount=159350, totalAmount=823300, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 7, 3), totalChallan=113, disposedChallan=41, pendingChallan=72, pendingAmount=540250, disposedAmount=164610, totalAmount=704860, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 7, 4), totalChallan=142, disposedChallan=39, pendingChallan=103, pendingAmount=619000, disposedAmount=276157, totalAmount=895157, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 7, 5), totalChallan=78, disposedChallan=31, pendingChallan=47, pendingAmount=346300, disposedAmount=164300, totalAmount=510600, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 7, 6), totalChallan=130, disposedChallan=34, pendingChallan=96, pendingAmount=731300, disposedAmount=204220, totalAmount=935520, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 7, 7), totalChallan=118, disposedChallan=27, pendingChallan=91, pendingAmount=772375, disposedAmount=130550, totalAmount=902925, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 7, 8), totalChallan=131, disposedChallan=52, pendingChallan=79, pendingAmount=993500, disposedAmount=381938, totalAmount=1375438, pendingCourt=0, disposedCourt=2, totalCourt=2),
#  Row(date=datetime.date(2015, 7, 9), totalChallan=259, disposedChallan=88, pendingChallan=171, pendingAmount=1804180, disposedAmount=749500, totalAmount=2553680, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 7, 10), totalChallan=154, disposedChallan=62, pendingChallan=92, pendingAmount=1088100, disposedAmount=509860, totalAmount=1597960, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 7, 11), totalChallan=244, disposedChallan=100, pendingChallan=144, pendingAmount=1521147, disposedAmount=730210, totalAmount=2251357, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 7, 12), totalChallan=95, disposedChallan=42, pendingChallan=53, pendingAmount=752800, disposedAmount=347500, totalAmount=1100300, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 7, 13), totalChallan=136, disposedChallan=53, pendingChallan=83, pendingAmount=684704, disposedAmount=467800, totalAmount=1152504, pendingCourt=2, disposedCourt=1, totalCourt=3),
#  Row(date=datetime.date(2015, 7, 14), totalChallan=121, disposedChallan=45, pendingChallan=76, pendingAmount=758770, disposedAmount=314850, totalAmount=1073620, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 7, 15), totalChallan=142, disposedChallan=55, pendingChallan=87, pendingAmount=959500, disposedAmount=403985, totalAmount=1363485, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 7, 16), totalChallan=113, disposedChallan=29, pendingChallan=84, pendingAmount=959300, disposedAmount=257300, totalAmount=1216600, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 7, 17), totalChallan=231, disposedChallan=72, pendingChallan=159, pendingAmount=1279497, disposedAmount=547770, totalAmount=1827267, pendingCourt=1, disposedCourt=2, totalCourt=3),
#  Row(date=datetime.date(2015, 7, 18), totalChallan=69, disposedChallan=25, pendingChallan=44, pendingAmount=490500, disposedAmount=163600, totalAmount=654100, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 7, 19), totalChallan=99, disposedChallan=20, pendingChallan=79, pendingAmount=486000, disposedAmount=88100, totalAmount=574100, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 7, 20), totalChallan=109, disposedChallan=28, pendingChallan=81, pendingAmount=713150, disposedAmount=135550, totalAmount=848700, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 7, 21), totalChallan=143, disposedChallan=48, pendingChallan=95, pendingAmount=654300, disposedAmount=336275, totalAmount=990575, pendingCourt=4, disposedCourt=0, totalCourt=4),
#  Row(date=datetime.date(2015, 7, 22), totalChallan=126, disposedChallan=47, pendingChallan=79, pendingAmount=736350, disposedAmount=483970, totalAmount=1220320, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 7, 23), totalChallan=156, disposedChallan=55, pendingChallan=101, pendingAmount=674951, disposedAmount=328370, totalAmount=1003321, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 7, 24), totalChallan=126, disposedChallan=37, pendingChallan=89, pendingAmount=589150, disposedAmount=187350, totalAmount=776500, pendingCourt=4, disposedCourt=0, totalCourt=4),
#  Row(date=datetime.date(2015, 7, 25), totalChallan=102, disposedChallan=39, pendingChallan=63, pendingAmount=546350, disposedAmount=209600, totalAmount=755950, pendingCourt=0, disposedCourt=5, totalCourt=5),
#  Row(date=datetime.date(2015, 7, 26), totalChallan=87, disposedChallan=33, pendingChallan=54, pendingAmount=416000, disposedAmount=220550, totalAmount=636550, pendingCourt=0, disposedCourt=2, totalCourt=2),
#  Row(date=datetime.date(2015, 7, 27), totalChallan=75, disposedChallan=28, pendingChallan=47, pendingAmount=491950, disposedAmount=198800, totalAmount=690750, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 7, 28), totalChallan=46, disposedChallan=18, pendingChallan=28, pendingAmount=175700, disposedAmount=117937, totalAmount=293637, pendingCourt=5, disposedCourt=0, totalCourt=5),
#  Row(date=datetime.date(2015, 7, 29), totalChallan=63, disposedChallan=21, pendingChallan=42, pendingAmount=465119, disposedAmount=117350, totalAmount=582469, pendingCourt=1, disposedCourt=1, totalCourt=2),
#  Row(date=datetime.date(2015, 7, 30), totalChallan=106, disposedChallan=39, pendingChallan=67, pendingAmount=459300, disposedAmount=312860, totalAmount=772160, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 7, 31), totalChallan=128, disposedChallan=47, pendingChallan=81, pendingAmount=560100, disposedAmount=361803, totalAmount=921903, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 8, 1), totalChallan=92, disposedChallan=26, pendingChallan=66, pendingAmount=756250, disposedAmount=130700, totalAmount=886950, pendingCourt=5, disposedCourt=1, totalCourt=6),
#  Row(date=datetime.date(2015, 8, 2), totalChallan=96, disposedChallan=42, pendingChallan=54, pendingAmount=573550, disposedAmount=346050, totalAmount=919600, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 8, 3), totalChallan=99, disposedChallan=31, pendingChallan=68, pendingAmount=356370, disposedAmount=199992, totalAmount=556362, pendingCourt=3, disposedCourt=0, totalCourt=3),
#  Row(date=datetime.date(2015, 8, 4), totalChallan=92, disposedChallan=29, pendingChallan=63, pendingAmount=431550, disposedAmount=108200, totalAmount=539750, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 8, 5), totalChallan=145, disposedChallan=70, pendingChallan=75, pendingAmount=824320, disposedAmount=977870, totalAmount=1802190, pendingCourt=2, disposedCourt=0, totalCourt=2),
#  Row(date=datetime.date(2015, 8, 6), totalChallan=98, disposedChallan=38, pendingChallan=60, pendingAmount=502700, disposedAmount=233140, totalAmount=735840, pendingCourt=4, disposedCourt=0, totalCourt=4),
#  Row(date=datetime.date(2015, 8, 7), totalChallan=105, disposedChallan=35, pendingChallan=70, pendingAmount=494570, disposedAmount=271020, totalAmount=765590, pendingCourt=6, disposedCourt=1, totalCourt=7),
#  Row(date=datetime.date(2015, 8, 8), totalChallan=96, disposedChallan=29, pendingChallan=67, pendingAmount=418300, disposedAmount=116900, totalAmount=535200, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 8, 9), totalChallan=64, disposedChallan=18, pendingChallan=46, pendingAmount=182100, disposedAmount=121800, totalAmount=303900, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 8, 10), totalChallan=93, disposedChallan=23, pendingChallan=70, pendingAmount=526169, disposedAmount=110600, totalAmount=636769, pendingCourt=1, disposedCourt=0, totalCourt=1),
#  Row(date=datetime.date(2015, 8, 11), totalChallan=76, disposedChallan=21, pendingChallan=55, pendingAmount=281850, disposedAmount=132030, totalAmount=413880, pendingCourt=4, disposedCourt=0, totalCourt=4),
#  Row(date=datetime.date(2015, 8, 12), totalChallan=73, disposedChallan=28, pendingChallan=45, pendingAmount=341150, disposedAmount=207130, totalAmount=548280, pendingCourt=2, disposedCourt=2, totalCourt=4),
#  Row(date=datetime.date(2015, 8, 13), totalChallan=99, disposedChallan=33, pendingChallan=66, pendingAmount=311300, disposedAmount=239750, totalAmount=551050, pendingCourt=3, disposedCourt=1, totalCourt=4),
#  Row(date=datetime.date(2015, 8, 14), totalChallan=111, disposedChallan=31, pendingChallan=80, pendingAmount=560050, disposedAmount=181460, totalAmount=741510, pendingCourt=1, disposedCourt=2, totalCourt=3),
#  Row(date=datetime.date(2015, 8, 15), totalChallan=47, disposedChallan=9, pendingChallan=38, pendingAmount=272500, disposedAmount=30510, totalAmount=303010, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 8, 16), totalChallan=62, disposedChallan=18, pendingChallan=44, pendingAmount=162050, disposedAmount=112225, totalAmount=274275, pendingCourt=0, disposedCourt=0, totalCourt=0),
#  Row(date=datetime.date(2015, 8, 17), totalChallan=73, disposedChallan=20, pendingChallan=53, pendingAmount=309300, disposedAmount=90300, totalAmount=399600, pendingCourt=0, disposedCourt=1, totalCourt=1),
#  Row(date=datetime.date(2015, 8, 18), totalChallan=149, disposedChallan=49, pendingChallan=100, pendingAmount=578896, disposedAmount=201449, totalAmount=780345, pendingCourt=1, disposedCourt=3, totalCourt=4),
#  Row(date=datetime.date(2015, 8, 19), totalChallan=192, disposedChallan=54, pendingChallan=138, pendingAmount=599350, disposedAmount=121690, totalAmount=721040, pendingCourt=2, disposedCourt=1, totalCourt=3),
# ...
#  Row(date=datetime.date(2017, 7, 17), totalChallan=2282, disposedChallan=1312, pendingChallan=970, pendingAmount=2067700, disposedAmount=4539970, totalAmount=6607670, pendingCourt=737, disposedCourt=161, totalCourt=898),
#  Row(date=datetime.date(2017, 7, 18), totalChallan=2672, disposedChallan=1419, pendingChallan=1253, pendingAmount=2690800, disposedAmount=6857802, totalAmount=9548602, pendingCourt=950, disposedCourt=170, totalCourt=1120),
#  Row(date=datetime.date(2017, 7, 19), totalChallan=2142, disposedChallan=1087, pendingChallan=1055, pendingAmount=2371650, disposedAmount=4503945, totalAmount=6875595, pendingCourt=789, disposedCourt=142, totalCourt=931),
#  Row(date=datetime.date(2017, 7, 20), totalChallan=2110, disposedChallan=1077, pendingChallan=1033, pendingAmount=2060761, disposedAmount=3975607, totalAmount=6036368, pendingCourt=786, disposedCourt=148, totalCourt=934),
#  Row(date=datetime.date(2017, 7, 21), totalChallan=1844, disposedChallan=990, pendingChallan=854, pendingAmount=1978190, disposedAmount=3819602, totalAmount=5797792, pendingCourt=654, disposedCourt=152, totalCourt=806),
#  Row(date=datetime.date(2017, 7, 22), totalChallan=2026, disposedChallan=1087, pendingChallan=939, pendingAmount=2238762, disposedAmount=4824807, totalAmount=7063569, pendingCourt=708, disposedCourt=139, totalCourt=847),
#  Row(date=datetime.date(2017, 7, 23), totalChallan=728, disposedChallan=401, pendingChallan=327, pendingAmount=521400, disposedAmount=2305170, totalAmount=2826570, pendingCourt=269, disposedCourt=62, totalCourt=331),
#  Row(date=datetime.date(2017, 7, 24), totalChallan=1868, disposedChallan=894, pendingChallan=974, pendingAmount=1577833, disposedAmount=3772743, totalAmount=5350576, pendingCourt=772, disposedCourt=100, totalCourt=872),
#  Row(date=datetime.date(2017, 7, 25), totalChallan=2059, disposedChallan=1127, pendingChallan=932, pendingAmount=1465178, disposedAmount=6044226, totalAmount=7509404, pendingCourt=744, disposedCourt=119, totalCourt=863),
#  Row(date=datetime.date(2017, 7, 26), totalChallan=3051, disposedChallan=1761, pendingChallan=1290, pendingAmount=3056800, disposedAmount=7006651, totalAmount=10063451, pendingCourt=990, disposedCourt=204, totalCourt=1194),
#  Row(date=datetime.date(2017, 7, 27), totalChallan=2522, disposedChallan=1438, pendingChallan=1084, pendingAmount=1867430, disposedAmount=6817058, totalAmount=8684488, pendingCourt=898, disposedCourt=199, totalCourt=1097),
#  Row(date=datetime.date(2017, 7, 28), totalChallan=2853, disposedChallan=1638, pendingChallan=1215, pendingAmount=1965600, disposedAmount=6821035, totalAmount=8786635, pendingCourt=962, disposedCourt=204, totalCourt=1166),
#  Row(date=datetime.date(2017, 7, 29), totalChallan=2846, disposedChallan=1529, pendingChallan=1317, pendingAmount=1912250, disposedAmount=5383223, totalAmount=7295473, pendingCourt=1004, disposedCourt=197, totalCourt=1201),
#  Row(date=datetime.date(2017, 7, 30), totalChallan=1251, disposedChallan=742, pendingChallan=509, pendingAmount=1147700, disposedAmount=2476682, totalAmount=3624382, pendingCourt=366, disposedCourt=88, totalCourt=454),
#  Row(date=datetime.date(2017, 7, 31), totalChallan=1740, disposedChallan=1005, pendingChallan=735, pendingAmount=1522850, disposedAmount=5399364, totalAmount=6922214, pendingCourt=569, disposedCourt=134, totalCourt=703),
#  Row(date=datetime.date(2017, 8, 1), totalChallan=2079, disposedChallan=920, pendingChallan=1159, pendingAmount=1921850, disposedAmount=6324202, totalAmount=8246052, pendingCourt=908, disposedCourt=141, totalCourt=1049),
#  Row(date=datetime.date(2017, 8, 2), totalChallan=3234, disposedChallan=2018, pendingChallan=1216, pendingAmount=2820940, disposedAmount=6340507, totalAmount=9161447, pendingCourt=953, disposedCourt=271, totalCourt=1224),
#  Row(date=datetime.date(2017, 8, 3), totalChallan=2353, disposedChallan=1147, pendingChallan=1206, pendingAmount=1975100, disposedAmount=5748269, totalAmount=7723369, pendingCourt=922, disposedCourt=184, totalCourt=1106),
#  Row(date=datetime.date(2017, 8, 4), totalChallan=2417, disposedChallan=1138, pendingChallan=1279, pendingAmount=1819700, disposedAmount=5830849, totalAmount=7650549, pendingCourt=1036, disposedCourt=165, totalCourt=1201),
#  Row(date=datetime.date(2017, 8, 5), totalChallan=1934, disposedChallan=930, pendingChallan=1004, pendingAmount=1704618, disposedAmount=5856623, totalAmount=7561241, pendingCourt=745, disposedCourt=153, totalCourt=898),
#  Row(date=datetime.date(2017, 8, 6), totalChallan=624, disposedChallan=278, pendingChallan=346, pendingAmount=785150, disposedAmount=1364140, totalAmount=2149290, pendingCourt=223, disposedCourt=31, totalCourt=254),
#  Row(date=datetime.date(2017, 8, 7), totalChallan=644, disposedChallan=109, pendingChallan=535, pendingAmount=502100, disposedAmount=160590, totalAmount=662690, pendingCourt=379, disposedCourt=20, totalCourt=399),
#  Row(date=datetime.date(2017, 8, 8), totalChallan=2185, disposedChallan=830, pendingChallan=1355, pendingAmount=1943550, disposedAmount=2811801, totalAmount=4755351, pendingCourt=985, disposedCourt=139, totalCourt=1124),
#  Row(date=datetime.date(2017, 8, 9), totalChallan=2956, disposedChallan=1655, pendingChallan=1301, pendingAmount=3334600, disposedAmount=6074500, totalAmount=9409100, pendingCourt=1007, disposedCourt=186, totalCourt=1193),
#  Row(date=datetime.date(2017, 8, 10), totalChallan=2294, disposedChallan=1274, pendingChallan=1020, pendingAmount=2049598, disposedAmount=7625272, totalAmount=9674870, pendingCourt=765, disposedCourt=144, totalCourt=909),
#  Row(date=datetime.date(2017, 8, 11), totalChallan=2455, disposedChallan=1150, pendingChallan=1305, pendingAmount=2066500, disposedAmount=5975755, totalAmount=8042255, pendingCourt=988, disposedCourt=206, totalCourt=1194),
#  Row(date=datetime.date(2017, 8, 12), totalChallan=1966, disposedChallan=935, pendingChallan=1031, pendingAmount=2276313, disposedAmount=5483249, totalAmount=7759562, pendingCourt=781, disposedCourt=152, totalCourt=933),
#  Row(date=datetime.date(2017, 8, 13), totalChallan=1165, disposedChallan=594, pendingChallan=571, pendingAmount=1198730, disposedAmount=3684513, totalAmount=4883243, pendingCourt=391, disposedCourt=74, totalCourt=465),
#  Row(date=datetime.date(2017, 8, 14), totalChallan=1605, disposedChallan=783, pendingChallan=822, pendingAmount=1576578, disposedAmount=4147535, totalAmount=5724113, pendingCourt=645, disposedCourt=92, totalCourt=737),
#  Row(date=datetime.date(2017, 8, 15), totalChallan=350, disposedChallan=93, pendingChallan=257, pendingAmount=242260, disposedAmount=959690, totalAmount=1201950, pendingCourt=166, disposedCourt=9, totalCourt=175),
#  Row(date=datetime.date(2017, 8, 16), totalChallan=2464, disposedChallan=1035, pendingChallan=1429, pendingAmount=1784940, disposedAmount=2726763, totalAmount=4511703, pendingCourt=1041, disposedCourt=158, totalCourt=1199),
#  Row(date=datetime.date(2017, 8, 17), totalChallan=1993, disposedChallan=993, pendingChallan=1000, pendingAmount=1962320, disposedAmount=4395715, totalAmount=6358035, pendingCourt=714, disposedCourt=96, totalCourt=810),
#  Row(date=datetime.date(2017, 8, 18), totalChallan=2286, disposedChallan=930, pendingChallan=1356, pendingAmount=1573300, disposedAmount=4865864, totalAmount=6439164, pendingCourt=1091, disposedCourt=130, totalCourt=1221),
#  Row(date=datetime.date(2017, 8, 19), totalChallan=1671, disposedChallan=768, pendingChallan=903, pendingAmount=1627000, disposedAmount=6022806, totalAmount=7649806, pendingCourt=723, disposedCourt=116, totalCourt=839),
#  Row(date=datetime.date(2017, 8, 20), totalChallan=1146, disposedChallan=356, pendingChallan=790, pendingAmount=887300, disposedAmount=1929715, totalAmount=2817015, pendingCourt=580, disposedCourt=72, totalCourt=652),
#  Row(date=datetime.date(2017, 8, 21), totalChallan=1789, disposedChallan=808, pendingChallan=981, pendingAmount=1815600, disposedAmount=4164990, totalAmount=5980590, pendingCourt=752, disposedCourt=95, totalCourt=847),
#  Row(date=datetime.date(2017, 8, 22), totalChallan=1718, disposedChallan=779, pendingChallan=939, pendingAmount=1306550, disposedAmount=4815886, totalAmount=6122436, pendingCourt=733, disposedCourt=95, totalCourt=828),
#  Row(date=datetime.date(2017, 8, 23), totalChallan=2159, disposedChallan=1105, pendingChallan=1054, pendingAmount=1736098, disposedAmount=4219875, totalAmount=5955973, pendingCourt=799, disposedCourt=119, totalCourt=918),
#  Row(date=datetime.date(2017, 8, 24), totalChallan=2175, disposedChallan=982, pendingChallan=1193, pendingAmount=1831700, disposedAmount=5458707, totalAmount=7290407, pendingCourt=879, disposedCourt=126, totalCourt=1005),
#  Row(date=datetime.date(2017, 8, 25), totalChallan=1834, disposedChallan=843, pendingChallan=991, pendingAmount=1299098, disposedAmount=4170216, totalAmount=5469314, pendingCourt=739, disposedCourt=94, totalCourt=833),
#  Row(date=datetime.date(2017, 8, 26), totalChallan=1822, disposedChallan=702, pendingChallan=1120, pendingAmount=1600050, disposedAmount=3519020, totalAmount=5119070, pendingCourt=839, disposedCourt=110, totalCourt=949),
#  Row(date=datetime.date(2017, 8, 27), totalChallan=844, disposedChallan=420, pendingChallan=424, pendingAmount=527950, disposedAmount=2680915, totalAmount=3208865, pendingCourt=314, disposedCourt=58, totalCourt=372),
#  Row(date=datetime.date(2017, 8, 28), totalChallan=1834, disposedChallan=874, pendingChallan=960, pendingAmount=1313229, disposedAmount=3709934, totalAmount=5023163, pendingCourt=715, disposedCourt=114, totalCourt=829),
#  Row(date=datetime.date(2017, 8, 29), totalChallan=2009, disposedChallan=948, pendingChallan=1061, pendingAmount=1945301, disposedAmount=4746478, totalAmount=6691779, pendingCourt=803, disposedCourt=176, totalCourt=979),
#  Row(date=datetime.date(2017, 8, 30), totalChallan=2601, disposedChallan=1517, pendingChallan=1084, pendingAmount=2059350, disposedAmount=4763995, totalAmount=6823345, pendingCourt=853, disposedCourt=180, totalCourt=1033),
#  Row(date=datetime.date(2017, 8, 31), totalChallan=1431, disposedChallan=890, pendingChallan=541, pendingAmount=1131354, disposedAmount=3231500, totalAmount=4362854, pendingCourt=401, disposedCourt=138, totalCourt=539),
#  Row(date=datetime.date(2017, 9, 1), totalChallan=1275, disposedChallan=629, pendingChallan=646, pendingAmount=1721640, disposedAmount=3752165, totalAmount=5473805, pendingCourt=447, disposedCourt=98, totalCourt=545),
#  Row(date=datetime.date(2017, 9, 2), totalChallan=618, disposedChallan=246, pendingChallan=372, pendingAmount=496500, disposedAmount=975430, totalAmount=1471930, pendingCourt=264, disposedCourt=32, totalCourt=296),
#  Row(date=datetime.date(2017, 9, 3), totalChallan=497, disposedChallan=313, pendingChallan=184, pendingAmount=755900, disposedAmount=2782490, totalAmount=3538390, pendingCourt=113, disposedCourt=39, totalCourt=152),
#  Row(date=datetime.date(2017, 9, 4), totalChallan=1663, disposedChallan=834, pendingChallan=829, pendingAmount=1781547, disposedAmount=4712856, totalAmount=6494403, pendingCourt=642, disposedCourt=116, totalCourt=758),
#  Row(date=datetime.date(2017, 9, 5), totalChallan=1585, disposedChallan=837, pendingChallan=748, pendingAmount=1983290, disposedAmount=7224062, totalAmount=9207352, pendingCourt=587, disposedCourt=105, totalCourt=692),
#  Row(date=datetime.date(2017, 9, 6), totalChallan=2231, disposedChallan=1433, pendingChallan=798, pendingAmount=2295900, disposedAmount=6768732, totalAmount=9064632, pendingCourt=606, disposedCourt=144, totalCourt=750),
#  Row(date=datetime.date(2017, 9, 7), totalChallan=1971, disposedChallan=969, pendingChallan=1002, pendingAmount=1798534, disposedAmount=5472384, totalAmount=7270918, pendingCourt=770, disposedCourt=93, totalCourt=863),
#  Row(date=datetime.date(2017, 9, 8), totalChallan=1583, disposedChallan=820, pendingChallan=763, pendingAmount=1599700, disposedAmount=5054146, totalAmount=6653846, pendingCourt=586, disposedCourt=81, totalCourt=667),
#  Row(date=datetime.date(2017, 9, 9), totalChallan=1604, disposedChallan=677, pendingChallan=927, pendingAmount=973050, disposedAmount=3929691, totalAmount=4902741, pendingCourt=746, disposedCourt=92, totalCourt=838),
#  Row(date=datetime.date(2017, 9, 10), totalChallan=1056, disposedChallan=468, pendingChallan=588, pendingAmount=1022160, disposedAmount=2330711, totalAmount=3352871, pendingCourt=449, disposedCourt=70, totalCourt=519),
#  Row(date=datetime.date(2017, 9, 11), totalChallan=2109, disposedChallan=1031, pendingChallan=1078, pendingAmount=1832375, disposedAmount=5443924, totalAmount=7276299, pendingCourt=843, disposedCourt=188, totalCourt=1031),
#  Row(date=datetime.date(2017, 9, 12), totalChallan=1995, disposedChallan=1076, pendingChallan=919, pendingAmount=1908759, disposedAmount=9379951, totalAmount=11288710, pendingCourt=684, disposedCourt=141, totalCourt=825),
#  Row(date=datetime.date(2017, 9, 13), totalChallan=2399, disposedChallan=1370, pendingChallan=1029, pendingAmount=1911403, disposedAmount=5531628, totalAmount=7443031, pendingCourt=823, disposedCourt=160, totalCourt=983),
#  Row(date=datetime.date(2017, 9, 14), totalChallan=1209, disposedChallan=382, pendingChallan=827, pendingAmount=1188390, disposedAmount=2531275, totalAmount=3719665, pendingCourt=646, disposedCourt=71, totalCourt=717),
#  Row(date=datetime.date(2017, 9, 15), totalChallan=1686, disposedChallan=825, pendingChallan=861, pendingAmount=1574230, disposedAmount=3490690, totalAmount=5064920, pendingCourt=685, disposedCourt=148, totalCourt=833),
#  Row(date=datetime.date(2017, 9, 16), totalChallan=1873, disposedChallan=976, pendingChallan=897, pendingAmount=1478150, disposedAmount=5782735, totalAmount=7260885, pendingCourt=746, disposedCourt=158, totalCourt=904),
#  Row(date=datetime.date(2017, 9, 17), totalChallan=977, disposedChallan=527, pendingChallan=450, pendingAmount=945300, disposedAmount=3078706, totalAmount=4024006, pendingCourt=348, disposedCourt=70, totalCourt=418),
#  Row(date=datetime.date(2017, 9, 18), totalChallan=2294, disposedChallan=1193, pendingChallan=1101, pendingAmount=2258200, disposedAmount=4769057, totalAmount=7027257, pendingCourt=844, disposedCourt=176, totalCourt=1020),
#  Row(date=datetime.date(2017, 9, 19), totalChallan=2575, disposedChallan=1278, pendingChallan=1297, pendingAmount=3633254, disposedAmount=6461644, totalAmount=10094898, pendingCourt=887, disposedCourt=209, totalCourt=1096),
#  Row(date=datetime.date(2017, 9, 20), totalChallan=4129, disposedChallan=2637, pendingChallan=1492, pendingAmount=3991700, disposedAmount=5600425, totalAmount=9592125, pendingCourt=1154, disposedCourt=288, totalCourt=1442),
#  Row(date=datetime.date(2017, 9, 21), totalChallan=2599, disposedChallan=1374, pendingChallan=1225, pendingAmount=2735775, disposedAmount=3761244, totalAmount=6497019, pendingCourt=918, disposedCourt=186, totalCourt=1104),
#  Row(date=datetime.date(2017, 9, 22), totalChallan=2018, disposedChallan=1155, pendingChallan=863, pendingAmount=2801550, disposedAmount=4296268, totalAmount=7097818, pendingCourt=566, disposedCourt=173, totalCourt=739),
#  Row(date=datetime.date(2017, 9, 23), totalChallan=2042, disposedChallan=1185, pendingChallan=857, pendingAmount=2087425, disposedAmount=3941666, totalAmount=6029091, pendingCourt=683, disposedCourt=174, totalCourt=857),
#  Row(date=datetime.date(2017, 9, 24), totalChallan=1258, disposedChallan=860, pendingChallan=398, pendingAmount=1383264, disposedAmount=3024312, totalAmount=4407576, pendingCourt=283, disposedCourt=82, totalCourt=365),
#  Row(date=datetime.date(2017, 9, 25), totalChallan=2195, disposedChallan=1320, pendingChallan=875, pendingAmount=2204150, disposedAmount=5638373, totalAmount=7842523, pendingCourt=699, disposedCourt=203, totalCourt=902),
#  Row(date=datetime.date(2017, 9, 26), totalChallan=2540, disposedChallan=1571, pendingChallan=969, pendingAmount=2029102, disposedAmount=6852940, totalAmount=8882042, pendingCourt=785, disposedCourt=219, totalCourt=1004),
#  ...]

# %%
df.count()
# Out:
# 4061

# %%
columns = len(df.columns)
print(columns)
# Out:
# 10

# %%
df.printSchema()
# Out:
# root
#  |-- date: date (nullable = true)
#  |-- totalChallan: integer (nullable = true)
#  |-- disposedChallan: integer (nullable = true)
#  |-- pendingChallan: integer (nullable = true)
#  |-- pendingAmount: integer (nullable = true)
#  |-- disposedAmount: integer (nullable = true)
#  |-- totalAmount: integer (nullable = true)
#  |-- pendingCourt: integer (nullable = true)
#  |-- disposedCourt: integer (nullable = true)
#  |-- totalCourt: integer (nullable = true)

# %%
df.show (5,False)
# Out:
# +----------+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+
# |date      |totalChallan|disposedChallan|pendingChallan|pendingAmount|disposedAmount|totalAmount|pendingCourt|disposedCourt|totalCourt|
# +----------+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+
# |2015-01-01|120         |29             |91            |588600       |116860        |705460     |1           |0            |1         |
# |2015-01-02|162         |39             |123           |663350       |281425        |944775     |1           |1            |2         |
# |2015-01-03|122         |34             |88            |596900       |286950        |883850     |4           |1            |5         |
# |2015-01-04|116         |27             |89            |967350       |301600        |1268950    |3           |2            |5         |
# |2015-01-05|162         |28             |134           |877654       |103000        |980654     |2           |0            |2         |
# +----------+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+
# only showing top 5 rows

# %%
df.repartition(2).write.format("csv") \
    .mode("overwrite") \
    .option("header", "true") \
    .save(path)

# %%
df.describe().show()
# Out:
# 26/03/01 12:06:09 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +-------+------------------+------------------+-----------------+-------------------+--------------------+--------------------+-----------------+------------------+------------------+
# |summary|      totalChallan|   disposedChallan|   pendingChallan|      pendingAmount|      disposedAmount|         totalAmount|     pendingCourt|     disposedCourt|        totalCourt|
# +-------+------------------+------------------+-----------------+-------------------+--------------------+--------------------+-----------------+------------------+------------------+
# |  count|              4061|              4061|             4061|               4061|                4061|                4061|             4061|              4061|              4061|
# |   mean|102564.29598621029| 39190.89509972913|63373.40088648116|9.998178130879094E7| 5.655994373356316E7| 1.565417250423541E8|31538.34819010096|5563.7631125338585| 37102.11130263482|
# | stddev|  94274.3099047864|30766.668065442063|69079.82083101527| 1.29508226564693E8|6.2583925115077384E7|1.7192330356549096E8|34442.07246235172| 4879.256999989784|37600.288253204395|
# |    min|                10|                 6|                3|              20400|                6700|               54400|                0|                 0|                 0|
# |    max|            332710|             96645|           280588|          565996093|          2071115652|          2147021053|           136032|             15910|            146748|
# +-------+------------------+------------------+-----------------+-------------------+--------------------+--------------------+-----------------+------------------+------------------+

# %%
monthly_df = df.groupBy(
    month("date").alias("month")
).agg(
    sum("totalChallan").alias("totalChallan"),
    sum("disposedChallan").alias("disposedChallan"),
    sum("pendingChallan").alias("pendingChallan"),
    sum("pendingAmount").alias("pendingAmount"),
    sum("disposedAmount").alias("disposedAmount"),
    sum("totalAmount").alias("totalAmount"),
    sum("pendingCourt").alias("pendingCourt"),
    sum("disposedCourt").alias("disposedCourt"),
    sum("totalCourt").alias("totalCourt")
)

# %%
yearly_df = df.groupBy(
    year("date").alias("year")
).agg(
    sum("totalChallan").alias("totalChallan"),
    sum("disposedChallan").alias("disposedChallan"),
    sum("pendingChallan").alias("pendingChallan"),
    sum("pendingAmount").alias("pendingAmount"),
    sum("disposedAmount").alias("disposedAmount"),
    sum("totalAmount").alias("totalAmount"),
    sum("pendingCourt").alias("pendingCourt"),
    sum("disposedCourt").alias("disposedCourt"),
    sum("totalCourt").alias("totalCourt")
)

# %%
monthly_df.show(5,False)
# Out:
# +-----+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+
# |month|totalChallan|disposedChallan|pendingChallan|pendingAmount|disposedAmount|totalAmount|pendingCourt|disposedCourt|totalCourt|
# +-----+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+
# |12   |37931314    |13399438       |24531876      |41052856303  |20113892108   |61166748411|10543311    |1786256      |12329567  |
# |1    |38347036    |13520202       |24826834      |39402739670  |19561151709   |58963891379|10472471    |1839020      |12311491  |
# |6    |34314635    |13577873       |20736762      |31772630055  |20361638384   |52134268439|10701694    |1984370      |12686064  |
# |3    |33078759    |13710026       |19368733      |29951514982  |21366102507   |51317617489|10303815    |1894969      |12198784  |
# |5    |31136535    |12080554       |19055981      |30211531965  |16956160733   |47167692698|10012124    |1771825      |11783949  |
# +-----+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+
# only showing top 5 rows

# %%
monthly_df.write.format("csv") \
    .mode("overwrite") \
    .partitionBy( "month") \
    .option("header", "true") \
    .save("/home/somnath/coding/pyspark/output_data/monthly_data")

# %%
yearly_df.write.format("csv") \
    .mode("overwrite") \
    .partitionBy( "year") \
    .option("header", "true") \
    .save("/home/somnath/coding/pyspark/output_data/yearly_data")

# %%
yearly_df.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[_groupingexpression#1176], functions=[sum(totalChallan#18), sum(disposedChallan#19), sum(pendingChallan#20), sum(pendingAmount#21), sum(disposedAmount#22), sum(totalAmount#23), sum(pendingCourt#24), sum(disposedCourt#25), sum(totalCourt#26)])
#    +- Exchange hashpartitioning(_groupingexpression#1176, 200), ENSURE_REQUIREMENTS, [plan_id=378]
#       +- HashAggregate(keys=[_groupingexpression#1176], functions=[partial_sum(totalChallan#18), partial_sum(disposedChallan#19), partial_sum(pendingChallan#20), partial_sum(pendingAmount#21), partial_sum(disposedAmount#22), partial_sum(totalAmount#23), partial_sum(pendingCourt#24), partial_sum(disposedCourt#25), partial_sum(totalCourt#26)])
#          +- Project [totalChallan#18, disposedChallan#19, pendingChallan#20, pendingAmount#21, disposedAmount#22, totalAmount#23, pendingCourt#24, disposedCourt#25, totalCourt#26, year(date#17) AS _groupingexpression#1176]
#             +- FileScan csv [date#17,totalChallan#18,disposedChallan#19,pendingChallan#20,pendingAmount#21,disposedAmount#22,totalAmount#23,pendingCourt#24,disposedCourt#25,totalCourt#26] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/somnath/coding/pyspark/input_data/echallan_daily_data.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<date:date,totalChallan:int,disposedChallan:int,pendingChallan:int,pendingAmount:int,dispos...

# %%
df_2015 = yearly_df.filter(yearly_df.year == 2015)
df_2015.show()
# Out:
# +----+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+
# |year|totalChallan|disposedChallan|pendingChallan|pendingAmount|disposedAmount|totalAmount|pendingCourt|disposedCourt|totalCourt|
# +----+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+
# |2015|      112492|          14952|         97540|    219092716|      55412297|  274505013|       70210|         2411|     72621|
# +----+------------+---------------+--------------+-------------+--------------+-----------+------------+-------------+----------+

# %%
yearly_df.repartition(4).write.format("CSV") \
    .option("header", "true") \
    .mode("overwrite") \
    .option("path", "/home/somnath/coding/pyspark/output_data/yearly_data/BUCKET") \
    .bucketBy(4, "year") \
    .saveAsTable("year_bucketed_table")

# %%
spark.table("year_bucketed_table").show()
# Out:
# +----+------------+---------------+--------------+-------------+--------------+------------+------------+-------------+----------+
# |year|totalChallan|disposedChallan|pendingChallan|pendingAmount|disposedAmount| totalAmount|pendingCourt|disposedCourt|totalCourt|
# +----+------------+---------------+--------------+-------------+--------------+------------+------------+-------------+----------+
# |2025|    97884423|       22955259|      74929164| 144158997231|   37850988379|182009985610|    35646527|      1794478|  37441005|
# |2018|     4317842|        3366850|        950992|   2016267241|    6686319692|  8702586933|      541373|       173800|    715173|
# |2022|    47649749|       23999582|      23650167|  36057961570|   36661025294| 72718986864|    13589745|      3702527|  17292272|
# |2023|    67911658|       27837346|      40074312|  65165178521|   42487725509|107652904030|    22325544|      4541276|  26866820|
# |2024|    81892378|       26316839|      55575539|  88702822632|   40065723712|128768546344|    28761158|      3394839|  32155997|
# |2020|    41190446|       18689557|      22500889|  21050666729|   20084568756| 41135235485|    11352355|      3264323|  14616678|
# |2021|    42401371|       20597664|      21803707|  24409206177|   25955875578| 50365081755|     9581743|      3627056|  13208799|
# |2019|    20628507|       13441022|       7187485|   4264870093|   15587127014| 19851997107|     4673928|      2025783|   6699711|
# |2026|    11527247|        1602984|       9924263|  19056295705|    2978920858| 22035216563|     1038677|        21577|   1060254|
# |2017|      593048|         289394|        303654|    584287433|    1173680480|  1757967913|      224313|        36764|    261077|
# |2016|      404445|          42776|        361669|    340367847|     102563933|   442931780|      271659|         9608|    281267|
# |2015|      112492|          14952|         97540|    219092716|      55412297|   274505013|       70210|         2411|     72621|
# +----+------------+---------------+--------------+-------------+--------------+------------+------------+-------------+----------+

# %%
spark.table("year_bucketed_table").count()
# Out:
# 12

# %%
spark.sql("SELECT * FROM year_bucketed_table ORDER BY year DESC").show()
# Out:
# +----+------------+---------------+--------------+-------------+--------------+------------+------------+-------------+----------+
# |year|totalChallan|disposedChallan|pendingChallan|pendingAmount|disposedAmount| totalAmount|pendingCourt|disposedCourt|totalCourt|
# +----+------------+---------------+--------------+-------------+--------------+------------+------------+-------------+----------+
# |2026|    11527247|        1602984|       9924263|  19056295705|    2978920858| 22035216563|     1038677|        21577|   1060254|
# |2025|    97884423|       22955259|      74929164| 144158997231|   37850988379|182009985610|    35646527|      1794478|  37441005|
# |2024|    81892378|       26316839|      55575539|  88702822632|   40065723712|128768546344|    28761158|      3394839|  32155997|
# |2023|    67911658|       27837346|      40074312|  65165178521|   42487725509|107652904030|    22325544|      4541276|  26866820|
# |2022|    47649749|       23999582|      23650167|  36057961570|   36661025294| 72718986864|    13589745|      3702527|  17292272|
# |2021|    42401371|       20597664|      21803707|  24409206177|   25955875578| 50365081755|     9581743|      3627056|  13208799|
# |2020|    41190446|       18689557|      22500889|  21050666729|   20084568756| 41135235485|    11352355|      3264323|  14616678|
# |2019|    20628507|       13441022|       7187485|   4264870093|   15587127014| 19851997107|     4673928|      2025783|   6699711|
# |2018|     4317842|        3366850|        950992|   2016267241|    6686319692|  8702586933|      541373|       173800|    715173|
# |2017|      593048|         289394|        303654|    584287433|    1173680480|  1757967913|      224313|        36764|    261077|
# |2016|      404445|          42776|        361669|    340367847|     102563933|   442931780|      271659|         9608|    281267|
# |2015|      112492|          14952|         97540|    219092716|      55412297|   274505013|       70210|         2411|     72621|
# +----+------------+---------------+--------------+-------------+--------------+------------+------------+-------------+----------+

# %%
# Run the SQL and store result in a DataFrame
result_df = spark.sql("SELECT * FROM year_bucketed_table ORDER BY year DESC")

# Save to CSV in an output folder
result_df.write.format("csv") \
    .mode("overwrite") \
    .option("header", "true") \
    .save("/home/somnath/coding/pyspark/output_data/yearly_data_sorted")

# %%
result_df.rdd.getNumPartitions()
# Out:
# 1

# %%
repartition_df = result_df.repartition(2)
repartition_df.rdd.getNumPartitions()
# Out:
# 2

# %%
# Repartition DataFrame by the 'year' column
result_df1 = result_df.repartition("year")

# Check how many partitions you now have
print(result_df1.rdd.getNumPartitions())
# Out:
# 1

# %%
spark.stop()
